# %%
import pandas as pd
import folium

# %%
googleSheetId = '15LtAukjlmXovxdvoAcPDQgalJmv6ZT7aYjmq8E5ilD0'

workSheetName = 'cent_df'

url = 'https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(
    googleSheetId, 
    workSheetName
)

df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-d94d0e2db69f> in <module>
#       8 )
#       9
# ---> 10 df = pd.read_csv(url)
#
# ~/Documents/GKM/Projects/Optimate/Evegii/ethiopia/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/Documents/GKM/Projects/Optimate/Evegii/ethiopia/venv/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     with parser:
# --> 463         return parser.read(nrows)
#     464
#     465
#
# ~/Documents/GKM/Projects/Optimate/Evegii/ethiopia/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1050     def read(self, nrows=None):
#    1051         nrows = validate_integer("nrows", nrows)
# -> 1052         index, columns, col_dict = self._engine.read(nrows)
#    1053
#    1054         if index is None:
#
# ~/Documents/GKM/Projects/Optimate/Evegii/ethiopia/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2054     def read(self, nrows=None):
#    2055         try:
# -> 2056             data = self._reader.read(nrows)
#    2057         except StopIteration:
#    2058             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 6, saw 2

# %%
df
# Out:
#            Collection  Century  \
# 0         EMML (HMML)       20
# 1         EMML (HMML)       17
# 2         EMML (HMML)       16
# 3         EMML (HMML)       20
# 4         EMML (HMML)       20
# ..                ...      ...
# 122  Ethio-SPaRe (UH)       19
# 123  Ethio-SPaRe (UH)       19
# 124  Ethio-SPaRe (UH)       20
# 125          BOr (BL)       18
# 126         GEM (PUL)       19
#
#                                                  Place  \
# 0        Savior of the World (Madhane Alam), Church of
# 1    Savior of the World (Madhane Alam), Church of ...
# 2                    Private library of Walga Mefrratu
# 3                                           Bookseller
# 4                            St. Takla Haymanot Church
# ..                                                 ...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                   Sanʿāfe, Eritrea
# 126  Eritrea; Garrett spent his whole time in Eritr...
#
#                                                 Region  Latitude  Longitude  \
# 0                    South: Addis Ababa, Qarānyo/Aqāqi   8.86824   38.79112
# 1                    South: Addis Ababa, Qarānyo/Aqāqi   8.86824   38.79112
# 2           South: Addis Ababa, Takla Haymanot quarter   8.98530   38.71711
# 3           South: Addis Ababa, Takla Haymanot quarter   8.98530   38.71711
# 4           South: Addis Ababa, Takla Haymanot quarter   8.98530   38.71711
# ..                                                 ...       ...        ...
# 122          Original Location: ʾAmbasat Kidāna Mǝḥrat  14.39483   39.40653
# 123          Original Location: ʾAgamyo Qǝddus Mikāʾel  14.40967   39.51811
# 124    Original Location: ʿĀddi Qiyāḥto Qǝddǝst Māryām  14.42711   39.45108
# 125  Looted from Madḫāne ʿĀlam, but may have been m...  14.70000   39.41667
# 126         Eritrea, Gheleb (or Keren or Asmara maybe)  15.82958   38.78174
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 17  \
# 0           NaN         NaN         NaN         NaN  ...          NaN
# 1           NaN         NaN         NaN         NaN  ...          NaN
# 2           NaN         NaN         NaN         NaN  ...          NaN
# 3           NaN         NaN         NaN         NaN  ...          NaN
# 4           NaN         NaN         NaN         NaN  ...          NaN
# ..          ...         ...         ...         ...  ...          ...
# 122         NaN         NaN         NaN         NaN  ...          NaN
# 123         NaN         NaN         NaN         NaN  ...          NaN
# 124         NaN         NaN         NaN         NaN  ...          NaN
# 125         NaN         NaN         NaN         NaN  ...          NaN
# 126         NaN         NaN         NaN         NaN  ...          NaN
#
#      Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 122          NaN          NaN          NaN          NaN          NaN
# 123          NaN          NaN          NaN          NaN          NaN
# 124          NaN          NaN          NaN          NaN          NaN
# 125          NaN          NaN          NaN          NaN          NaN
# 126          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 122          NaN          NaN          NaN          NaN
# 123          NaN          NaN          NaN          NaN
# 124          NaN          NaN          NaN          NaN
# 125          NaN          NaN          NaN          NaN
# 126          NaN          NaN          NaN          NaN
#
# [127 rows x 27 columns]
